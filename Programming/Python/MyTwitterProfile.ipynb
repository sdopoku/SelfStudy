# %%
# set up appropriate modules

# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import csv
import analyze
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
csvreader=csv.reader(open('twitter/tweets.csv'), delimiter=',', quotechar='"')
csvreader.next()
csvreader.next()
# Out:
# ['437540103905222656',
#  '',
#  '',
#  '2014-02-23 10:51:04 +0000',
#  '<a href="http://twitter.com/tweetbutton" rel="nofollow">Tweet Button</a>',
#  '"If your school or job forces you into repetition, and quitting isn\xe2\x80\x99t an option, learn Python..." by @dasmithii https://t.co/NXOtAMY0HT',
#  '',
#  '',
#  '',
#  'https://medium.com/trapped-in-high-school/640538e599bb']

# %%
# %run analyze.py --dir="twitter"
# Out:
# Loaded 1173 tweets
# [('2013-12', 120), ('2012-05', 104), ('2012-06', 98), ('2013-11', 91), ('2013-04', 84), ('2012-10', 67), ('2013-02', 58), ('2013-03', 52), ('2012-07', 52), ('2012-11', 49)]
# [('2013-12', 120), ('2012-05', 104), ('2012-06', 98), ('2013-11', 91), ('2013-04', 84), ('2012-10', 67), ('2013-02', 58), ('2013-03', 52), ('2012-07', 52), ('2012-11', 49)]
# ...

# %%
# %run derivative.py
# Out:
# Enter polynomial expression: b^5 + 6x^2
# Enter 1 or 2 for 1st and 2nd derivative respectively: 2
# Derivative: 20b^3+12
# Enter polynomial expression: b^5+6b^2
# Enter 1 or 2 for 1st and 2nd derivative respectively: 1
# Derivative: 5b^4+12b
# Enter polynomial expression: quit
# Hope this was helpful! Bye :)

# %%
# %run derivative.py b^5+6b^2 0
# Out:
# b^5+6b^2

# %%
# %run derivative.py b^5+6b^2 1
# Out:
# 5b^4+12b

# %%
# %run derivative.py b^5+6b^2 2
# Out:
# 20b^3+12

# %%
# %run derivative.py b^5+6b^2 3
# Out:
# 60b^2

# %%
# %run derivative.py b^5+6b^2 4
# Out:
# 120b

# %%
# %run derivative.py b^5+6b^2 5
# Out:
# 120

# %%
# %run derivative.py b^5+6b^2 6
# Out:
# 0

# %%
# %run derivative.py b^5+-6b^2 1
# Out:
# 5b^4+-12b
